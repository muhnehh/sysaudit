# %% [markdown]
# # 03 FPS and Figures
# Compute flip predictability and render paper-ready plots.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.probes.hidden_state_capture import compute_fps
from src.metrics import compute_qag

# %% [markdown]
# ## Outputs
# - QAG table with confidence intervals
# - RDPS shift plots by precision
# - FPS ROC/AUC summary and threshold analysis
